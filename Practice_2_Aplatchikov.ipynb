# %% [markdown]
# **Pandas**

# %% [markdown]
# Сегодня мы работаем:
# - с библиотекой Pandas
# - проведем анализ данных
# - построим график с библиотекой `matpotlib`

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1cq9JDz8-zwzoGL6udiT_ogHHRWdnsd1q' -O math_students.csv
# Out:
# --2026-09-24 04:41:58--  https://docs.google.com/uc?export=download&id=1cq9JDz8-zwzoGL6udiT_ogHHRWdnsd1q
# Resolving docs.google.com (docs.google.com)... 173.194.216.138, 173.194.216.113, 173.194.216.101, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1cq9JDz8-zwzoGL6udiT_ogHHRWdnsd1q&export=download [following]
# --2026-09-24 04:41:58--  https://drive.usercontent.google.com/download?id=1cq9JDz8-zwzoGL6udiT_ogHHRWdnsd1q&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.107.132, 2607:f8b0:400c:c07::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42379 (41K) [application/octet-stream]
# Saving to: ‘math_students.csv’
#
# ...

# %% [markdown]
# Загрузим данные и посмотрим

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('math_students.csv')
# функция .head(n) выводит первые n строк таблицы (по умолчанию 5)
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# Аналогично можно смотреть не на верхние строки таблицы, а на нижние

# %%
data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.drop('G3',axis=1)
#data.drop(['G1','G2'],axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Проверим есть ли пропущенные значиения

# %%
#data.isnull()
#data.isnull().any()
data.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# Итак, пропусков нет
#
# По любой функции можно получить информацию из документации

# %%
#help(pd.read_csv)
# Или гугл

# %% [markdown]
# Можно вывести статистику по значениям признаков

# %%
data.shape
# Out:
# (395, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Какие значения принимает `guardian`

# %%
#data['guardian']
data['guardian'].unique() #Уникальные значения какие
# Out:
# array(['mother', 'father', 'other'], dtype=object)

# %%
data['guardian'].nunique() # Сколько уникальных параметров
# Out:
# 3

# %%
data['guardian'].value_counts() #Сколько раз втречается каждый пар-тр
# Out:
# guardian
# mother    273
# father     90
# other      32
# Name: count, dtype: int64

# %%
#data['internet'].unique()
data['internet'].value_counts()
# Out:
# internet
# yes    329
# no      66
# Name: count, dtype: int64

# %%
data['higher'].value_counts()
# Out:
# higher
# yes    375
# no      20
# Name: count, dtype: int64

# %%
data['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data['school'].value_counts()
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %% [markdown]
# Выведем тех сутдентов, опекуном которых  является мама, которая работает учителем или на дому

# %%
data[(data['guardian'] == 'mother') & ((data['Mjob'] == 'teacher') | (data['Mjob'] == 'at_home'))]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 13      GP   M   15       U     GT3       T     4     3  teacher     other
# 20      GP   M   15       U     GT3       T     4     3  teacher     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 379     MS   F   17       R     GT3       T     3     1  at_home     other
# 385     MS   F   18       R     GT3       T     2     2  at_home     other
# 386     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1  teacher  services
#
# ...

# %% [markdown]
# Task 1

# %%
data[(data['guardian'] == 'father') & (data['internet'] == 'no')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 35      GP   F   15       U     GT3       T     2     3     other     other
# 52      GP   M   15       U     LE3       A     4     2    health    health
# 92      GP   F   16       U     LE3       T     3     1     other     other
# 105     GP   F   15       U     GT3       A     3     3     other    health
# 116     GP   M   15       U     GT3       T     4     4     other   teacher
# 182     GP   F   17       U     GT3       T     2     4  services  services
# 218     GP   F   17       U     GT3       T     2     3   at_home     other
# 308     GP   M   19       R     GT3       T     3     3     other  services
# 355     MS   F   18       U     GT3       T     3     3  services  services
# 364     MS   F   17       R     GT3       T     1     2     other  services
# ...

# %% [markdown]
# $$
# alc = \frac[]
# $$

# %%
data['alc'] = (5 * data['Dalc'] + 2 * data["Walc"])/7
data['alc']
# Out:
# 0      1.000000
# 1      1.000000
# 2      2.285714
# 3      1.000000
# 4      1.285714
#          ...
# 390    4.285714
# 391    3.285714
# 392    3.000000
# 393    3.285714
# 394    3.000000
# Name: alc, Length: 395, dtype: float64

# %%
data.shape
# Out:
# (395, 34)

# %% [markdown]
# Проанализируем взаимосвязь кол-ва пропусков и успехов в учебе. Посмотрим на распределение кол-ва пропусков у учеников

# %%
plt.figure(figsize=(10,7))
plt.title('Absences distribution')

data['absences'].hist()

plt.xlabel('Absences')
plt.ylabel('Number of students')
# Out:
# Text(0, 0.5, 'Number of students')

# %%
mean_absences = data['absences'].mean()
study_few_absences = data[data['absences'] <= mean_absences]
study_many_absences = data[data['absences'] > mean_absences]

# %%
study_few_absences.shape[0]
# Out:
# 249

# %%
study_many_absences.shape[0]
# Out:
# 146

# %%
study_few_absences['G3'].mean()
# Out:
# np.float64(10.168674698795181)

# %%
study_many_absences['G3'].mean()
# Out:
# np.float64(10.835616438356164)

# %% [markdown]
# Данные можно группировать

# %%
data['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data_by_school = data.groupby('school')

# %%
data_by_school.describe()['G3']
# Out:
#         count       mean       std  min  25%   50%    75%   max
# school
# GP      349.0  10.489971  4.625397  0.0  8.0  11.0  14.00  20.0
# MS       46.0   9.847826  4.237229  0.0  8.0  10.0  12.75  19.0

# %%
data_by_school.describe()['traveltime']
# Out:
#         count      mean       std  min  25%  50%  75%  max
# school
# GP      349.0  1.386819  0.666910  1.0  1.0  1.0  2.0  4.0
# MS       46.0  1.913043  0.755015  1.0  1.0  2.0  2.0  4.0

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'alc'],
#       dtype='object')

# %% [markdown]
# 1)Какая причина выбора школы была самой частой? В качестве ответа приведите соответствующее значение признака.

# %% [markdown]
# 2)Найдите количество студентов, у родителей которых нет никакого образования.

# %% [markdown]
# 3)Найдите минимальный возраст учащегося школы Mousinho da Silveira.

# %% [markdown]
# 4)Найдите количество студентов, имеющих нечетное число пропусков

# %% [markdown]
# Задание **1**

# %%
reasons_count = data['reason'].value_counts()
reason_main = reasons_count.max()
print(reason_main)
# Out:
# 145

# %% [markdown]
# Задание 2

# %%
stupid_par = data[(data['Medu'] == '0') & (data['Fedu'] == '0')]
stupid_par.shape[0]
# Out:
# 0

# %% [markdown]
# Задание 3

# %%
st_ms = data[data['school'] == 'MS']
min_age = st_ms['age'].min()
print(min_age)
# Out:
# 17

# %% [markdown]
# Задание 4

# %%
absent_odd_values = data[data['absences'] % 2 != 0]
absent_odd_values.shape[0]
# Out:
# 41
